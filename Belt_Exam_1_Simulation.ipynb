# %% [markdown]
# <a href="https://colab.research.google.com/github/Markohf/CD_Flash_DS/blob/main/Belt_Exam_1_Simulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Contexto
#
# La tarea es limpiar y explorar los datos para una organización sin fines de lucro enfocada en promover y aumentar las tasas de alfabetización en jóvenes usando estos datos de la tasa de alfabetización. Esta organización está interesada en entender dónde deberían enfocarse para su siguiente proyecto y qué estrategias usar para tener un mayor impacto en aumentar la tasa de alfabetización en lo jóvenes en esa área.

# %%
#Montamos drive en colab.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importamos las bibliotecas que vamos a usar.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
#Importamos el dataset a usar.
data = '/content/drive/MyDrive/Flashcamp - Data Science/BBDD/Belt Exam 1 - Simulation (literacy_rates.csv).csv'
df = pd.read_csv(data)
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4950 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 232.4+ KB

# %%
df[(df['Country'] == "Afghanistan") | (df['Country'] == "Uzbekistan")].groupby(['Country', 'Region']).size()
# Out:
# Country      Region
# Afghanistan  Central and Southern Asia    21
# Uzbekistan   Central and Southern Asia    45
# dtype: int64

# %%
df['Region'].fillna('Central and Southern Asia', inplace=True)
df
# Out:
#                          Region      Country  Year    Age  Gender  \
# 0     Central and Southern Asia  Afghanistan  2011    15+  female
# 1     Central and Southern Asia  Afghanistan  2011    15+    male
# 2     Central and Southern Asia  Afghanistan  2011    15+   total
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# ...                         ...          ...   ...    ...     ...
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# 4951         Sub-Saharan Africa     Zimbabwe  2014  25-64   total
# 4952         Sub-Saharan Africa     Zimbabwe  2014    65+  female
# 4953         Sub-Saharan Africa     Zimbabwe  2014    65+    male
# 4954         Sub-Saharan Africa     Zimbabwe  2014    65+   total
#
#            Literacy rate
# 0              0.1761206
# 1               0.454171
# 2              0.3174112
# 3              0.3211322
# 4              0.6187907
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4955 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 232.4+ KB

# %%
df.head()
# Out:
#                       Region      Country  Year    Age  Gender Literacy rate
# 0  Central and Southern Asia  Afghanistan  2011    15+  female     0.1761206
# 1  Central and Southern Asia  Afghanistan  2011    15+    male      0.454171
# 2  Central and Southern Asia  Afghanistan  2011    15+   total     0.3174112
# 3  Central and Southern Asia  Afghanistan  2011  15-24  female     0.3211322
# 4  Central and Southern Asia  Afghanistan  2011  15-24    male     0.6187907

# %%
df['Literacy rate'] = df['Literacy rate'].astype(float)
df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0811845d4e06> in <cell line: 1>()
# ----> 1 df['Literacy rate'] = df['Literacy rate'].astype(float)
#       2 df.info()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6238         else:
#    6239             # else, only a single dtype is given
# -> 6240             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241             return self._constructor(new_data).__finalize__(self, method="astype")
#    6242
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     446
#     447     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     449
# ...

# %%
df[df['Literacy rate'] == '45.384%']
# Out:
#                        Region      Country  Year    Age Gender Literacy rate
# 18  Central and Southern Asia  Afghanistan  2018  25-64   male       45.384%

# %%
df['Literacy rate'][18] = 0.45384
# Out:
# <ipython-input-13-0fd617339f40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Literacy rate'][18] = 0.45384

# %%
df['Literacy rate'][18]
# Out:
# 0.45384

# %%
df['Literacy rate'] = df['Literacy rate'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4955 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 232.4+ KB

# %%
df.describe().T
# Out:
#                 count         mean       std          min          25%  \
# Year           4955.0  2013.987891  2.746204  2010.000000  2011.000000
# Literacy rate  4955.0     0.816947  0.232560     0.004025     0.722507
#
#                        50%          75%     max
# Year           2014.000000  2016.000000  2018.0
# Literacy rate     0.930676     0.985078     1.0

# %%
df['Age'].value_counts()
# Out:
# 15+      1260
# 15-24    1239
# 25-64    1239
# 65+      1217
# Name: Age, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# female    1652
# total     1652
# male      1651
# Name: Gender, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4955 entries, 0 to 4954
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         4955 non-null   object
#  1   Country        4955 non-null   object
#  2   Year           4955 non-null   int64
#  3   Age            4955 non-null   object
#  4   Gender         4955 non-null   object
#  5   Literacy rate  4955 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 232.4+ KB

# %%
df.t1 = df[(df['Gender'] != 'total') & (df['Age'] != '15+')]
df.t1
# Out:
# <ipython-input-22-0fe6deffc0d4>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.t1 = df[(df['Gender'] != 'total') & (df['Age'] != '15+')]
#                          Region      Country  Year    Age  Gender  \
# 3     Central and Southern Asia  Afghanistan  2011  15-24  female
# 4     Central and Southern Asia  Afghanistan  2011  15-24    male
# 6     Central and Southern Asia  Afghanistan  2011  25-64  female
# 7     Central and Southern Asia  Afghanistan  2011  25-64    male
# 9     Central and Southern Asia  Afghanistan  2011    65+  female
# ...                         ...          ...   ...    ...     ...
# 4947         Sub-Saharan Africa     Zimbabwe  2014  15-24    male
# 4949         Sub-Saharan Africa     Zimbabwe  2014  25-64  female
# 4950         Sub-Saharan Africa     Zimbabwe  2014  25-64    male
# ...

# %%
df.t1['Gender'].value_counts()
# Out:
# female    1232
# male      1231
# Name: Gender, dtype: int64

# %%
df.t1['Age'].value_counts()
# Out:
# 15-24    826
# 25-64    826
# 65+      811
# Name: Age, dtype: int64

# %%
df.t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2463 entries, 3 to 4953
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Region         2463 non-null   object
#  1   Country        2463 non-null   object
#  2   Year           2463 non-null   int64
#  3   Age            2463 non-null   object
#  4   Gender         2463 non-null   object
#  5   Literacy rate  2463 non-null   float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 134.7+ KB
